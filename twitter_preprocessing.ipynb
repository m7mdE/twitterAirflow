# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
import preprocessor as p
stopwords = nltk.corpus.stopwords.words('english')
pd.set_option('display.max_colwidth', 100)

# %%
df = pd.read_csv('tweets.csv')
df.head()
# Out:
#       author  \
# 0  katyperry
# 1  katyperry
# 2  katyperry
# 3  katyperry
# 4  katyperry
#
#                                                                                                content  \
# 0                            Is history repeating itself...?#DONTNORMALIZEHATE https://t.co/ngG11quhmK
# 1  @barackobama Thank you for your incredible grace in leadership and for being an exceptional… htt...
# 2                                                                  Life goals. https://t.co/XIn1qKMKQl
# 3                                                              Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4                                  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ https://t.co/0shuUYUBEv
#
#   country         date_time            id language  latitude  longitude  \
# 0     NaN  12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# 1     NaN  11/01/2017 08:38  8.191010e+17       en       NaN        NaN
# 2     NaN  11/01/2017 02:52  8.190140e+17       en       NaN        NaN
# 3     NaN  11/01/2017 02:44  8.190120e+17       en       NaN        NaN
# 4     NaN  10/01/2017 05:22  8.186890e+17       en       NaN        NaN
#
#    number_of_likes  number_of_shares
# 0             7900              3472
# 1             3689              1380
# 2            10341              2387
# 3            10774              2458
# 4            17620              4655

# %%
print(f'There are {df.shape[0]} columns and {df.shape[1]} rows')
# Out:
# There are 52542 columns and 10 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52542 entries, 0 to 52541
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   author            52542 non-null  object
#  1   content           52542 non-null  object
#  2   country           36 non-null     object
#  3   date_time         52542 non-null  object
#  4   id                52542 non-null  float64
#  5   language          52542 non-null  object
#  6   latitude          1 non-null      float64
#  7   longitude         1 non-null      float64
#  8   number_of_likes   52542 non-null  int64
#  9   number_of_shares  52542 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# Let's drop some columns which not be useful to machine learning models
#
# #### Create Function to Clean Text
#
# - Removing Punctuation
# - Tokenizing
# - Removing Stopwords

# %%
# dropping unnecessary columns
df = df.drop(columns=[
    'country', 'date_time', 'id', 'language', 
    'latitude', 'longitude'], axis=1)
df.columns = ['author', 'text', 'likes', 'shares']
df.head()
# Out:
#       author  \
# 0  katyperry
# 1  katyperry
# 2  katyperry
# 3  katyperry
# 4  katyperry
#
#                                                                                                   text  \
# 0                            Is history repeating itself...?#DONTNORMALIZEHATE https://t.co/ngG11quhmK
# 1  @barackobama Thank you for your incredible grace in leadership and for being an exceptional… htt...
# 2                                                                  Life goals. https://t.co/XIn1qKMKQl
# 3                                                              Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4                                  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ https://t.co/0shuUYUBEv
#
#    likes  shares
# 0   7900    3472
# 1   3689    1380
# 2  10341    2387
# 3  10774    2458
# 4  17620    4655

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
sentences = ["Check out this cool website: https://example.com",
             "Hey @username, nice to meet you!",
             "Using #Python for data analysis is awesome!"]
sentences

for sentence in sentences:
    tokens = re.split('\W+', sentence)
    # empty = [word for word in tokens if word not in '']
    print(tokens)
# Out:
# ['Check', 'out', 'this', 'cool', 'website', 'https', 'example', 'com']
# ['Hey', 'username', 'nice', 'to', 'meet', 'you', '']
# ['Using', 'Python', 'for', 'data', 'analysis', 'is', 'awesome', '']

# %%
# Initialize preprocessor options
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.HASHTAG)
# Iterate over each sentence
for sentence in sentences:
    # Clean the sentence using preprocessor
    cleaned_sentence = p.clean(sentence)
    text = ''.join([word.lower() for word in cleaned_sentence if word not in string.punctuation])
    print(text)
# Out:
# check out this cool website
# hey  nice to meet you
# using for data analysis is awesome

# %%
# Initialize preprocessor options
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.HASHTAG)
def clean_text(text):
    # Remove URLs, hashtags, and mentions using preprocessor
    cleaned_text = p.clean(text)
    # Remove punctuation and convert to lowercase
    text = ''.join([word.lower() for word in cleaned_text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    empty_char = [word for word in tokens if word not in '']
    text = [word for word in empty_char if word not in stopwords]
    return text

# %%
df['clean_text'] = df['text'].apply(lambda x: clean_text(x))
df.head()
# Out:
#       author  \
# 0  katyperry
# 1  katyperry
# 2  katyperry
# 3  katyperry
# 4  katyperry
#
#                                                                                                   text  \
# 0                            Is history repeating itself...?#DONTNORMALIZEHATE https://t.co/ngG11quhmK
# 1  @barackobama Thank you for your incredible grace in leadership and for being an exceptional… htt...
# 2                                                                  Life goals. https://t.co/XIn1qKMKQl
# 3                                                              Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4                                  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ https://t.co/0shuUYUBEv
#
#    likes  shares                                           clean_text
# 0   7900    3472                                 [history, repeating]
# 1   3689    1380  [thank, incredible, grace, leadership, exceptional]
# 2  10341    2387                                        [life, goals]
# 3  10774    2458                                              [right]
# 4  17620    4655                                      [sisters, doin]

# %% [markdown]
# Let's find out if there are empty arrays after the preprocessing

# %%
df[df['clean_text'].apply(len) == 0]
# Out:
#           author                                              text  likes  \
# 23     katyperry                      Same https://t.co/98vBUp7BzI   4236
# 59     katyperry                         🔮 https://t.co/aFzxsIRfhn   9348
# 66     katyperry                                              🎣🐟🐠🐋  10197
# 151    katyperry                                                 🎣   7885
# 168    katyperry                                       #KarlBecker   4786
# ...          ...                                               ...    ...
# 52451   ddlovato                    ❤️🌴☀️💄💋 http://t.co/64FlAWsv2s  15489
# 52485   ddlovato                    #nudezz http://t.co/Q0H0RNjQUf  14845
# 52504   ddlovato  #sketchers #buttsweat 💪👍💦 http://t.co/YEFHSB16p2  14292
# 52540   ddlovato                         ❄️ http://t.co/sHCFdPpGPa  15985
# 52541   ddlovato                     ❤️❄️✈️ http://t.co/ixmB5lv17Z  16193
#
#        shares clean_text
# 23       1143         []
# 59       2395         []
# 66       4432         []
# 151      3039         []
# 168      1308         []
# ...       ...        ...
# 52451   10967         []
# 52485    9875         []
# 52504    9012         []
# 52540   10456         []
# 52541   10822         []
#
# [2792 rows x 5 columns]

# %% [markdown]
# Let's remove 2,792 rows of empty arrays as this won't be suitable for our model

# %%
df.drop(df[df['clean_text'].apply(len) == 0].index, inplace=True)

# %%
# Sanity Check
df[df['clean_text'].apply(len) == 0]
# Out:
# Empty DataFrame
# Columns: [author, text, likes, shares, clean_text]
# Index: []
